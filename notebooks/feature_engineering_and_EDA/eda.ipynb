# %% [markdown]
# ## Exploratory Data Analysis (EDA) Workflow

# %% [markdown]
# ### 1. Introduction
# - **Objective:** Describe the purpose of the analysis.
# - **Dataset Overview:** Briefly explain the source and nature of the data.
# - **Columns / Features:** List or describe important columns.
#
# ### 2. Import Libraries
#
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline
#
#
# ### 3. Load Data
#
# df = pd.read_csv('your_dataset.csv')
# df.head()
#
#
# ### 4. Basic Data Info
# Check shape, data types, missing values, duplicates, and basic statistics.
#
# print("Rows, Columns:", df.shape)
# print(df.dtypes)
# print(df.isnull().sum())
# print(df.duplicated().sum())
# df.describe(include='all')
#
#
# ### 5. Data Cleaning
# Handle missing values, duplicates, and incorrect data types.
#
# df = df.drop_duplicates()
# df['column_name'].fillna(df['column_name'].median(), inplace=True)
# df['date_column'] = pd.to_datetime(df['date_column'])
#
#
# ### 6. Univariate Analysis
# Analyze each feature individually using plots and statistics.
#
# sns.countplot(x='categorical_column', data=df)
# plt.show()
#
# sns.histplot(df['numerical_column'], kde=True)
# plt.show()
#
# sns.boxplot(x='numerical_column', data=df)
# plt.show()
#
#
# ### 7. Bivariate Analysis
# Explore relationships between two variables.
#
# sns.scatterplot(x='num_col1', y='num_col2', data=df)
# plt.show()
#
# sns.boxplot(x='categorical_column', y='numerical_column', data=df)
# plt.show()
#
# corr = df.corr()
# sns.heatmap(corr, annot=True, cmap='coolwarm')
# plt.show()
#
#
# ### 8. Multivariate Analysis
# Explore interactions among multiple variables.
#
# sns.pairplot(df, hue='target_column')
# plt.show()
#
#
# ### 9. Feature Engineering (Optional)
# Create or transform features to improve insights or modeling.
#
# df['new_feature'] = df['feature1'] / df['feature2']
#
#
# ### 10. Summary / Insights
# Highlight key patterns, trends, correlations, and potential anomalies.
#
# Suggest next steps for modeling or deeper analysis.

# %% [markdown]
# ---------------------------------------------------------------

# %% [markdown]
# 1️⃣ One-Line EDA Checklist
#
# Understand → Load → Inspect → Clean → Univariate → Bivariate → Multivariate → Outliers → Transform → Insights
#
# 2️⃣ EDA Steps with Python Examples (Brief)
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# 1. Load Data
# df = pd.read_csv("data.csv")
#
# 2. Initial Inspection
# df.head()
# df.shape
# df.info()
# df.describe()
#
# 3. Data Quality Checks
# df.isnull().sum()
# df.duplicated().sum()
#
# 4. Univariate Analysis
# sns.histplot(df['age'])
# sns.boxplot(x=df['salary'])
#
# 5. Bivariate Analysis
# sns.scatterplot(x='age', y='salary', data=df)
# sns.barplot(x='gender', y='salary', data=df)
#
# 6. Multivariate Analysis
# sns.heatmap(df.corr(), annot=True)
# sns.pairplot(df)
#
# 7. Outlier Detection
# sns.boxplot(x=df['salary'])
#
# 8. Feature Transformation
# df['gender'] = df['gender'].map({'Male': 1, 'Female': 0})
#
# 9. Insights
#
# Identify trends
#
# Decide next steps (cleaning, modeling)
#
# 3️⃣ EDA for Machine Learning Projects (Structured)
# Step 1: Problem Understanding
#
# Classification / Regression?
#
# Target variable
#
# Evaluation metric
#
# Step 2: Target Variable Analysis
# df['target'].value_counts()
# sns.countplot(x='target', data=df)
#
# Step 3: Feature vs Target
#
# Numerical vs target → boxplot
#
# Categorical vs target → barplot
#
# sns.boxplot(x='target', y='age', data=df)
#
# Step 4: Correlation & Multicollinearity
# df.corr()
#
# Step 5: Data Imbalance Check
# df['target'].value_counts(normalize=True)
#
# Step 6: Feature Engineering Decisions
#
# Drop useless features
#
# Encode categoricals
#
# Scale numericals
#
# Step 7: Final EDA Summary
#
# Important features
#
# Risks (outliers, imbalance)
#
# Modeling strategy
#
# 🧠 Pro Tip (Interview-Friendly Line)
#
# “EDA is the process of understanding data structure, quality, distributions, relationships, and patterns to make informed preprocessing and modeling decisions.”

# %% [markdown]
# ## wine EDA

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/winequality-red.csv")
df.head()

# %%
#summary of the dataset
df.info()

# %%
#statistical descriptive summary
df.describe()

# %%
df.shape

# %%
df.columns

# %%
df['quality'].unique()

# %%
df.isnull().sum()

# %% [markdown]
# ### finding Duplicate records:

# %%
df[df.duplicated()]

# %%
# removing duplicates
df.drop_duplicates(inplace=True)

# %%
df.head()

# %%
df.shape

# %%
df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)

# %%
df.quality.value_counts()

# %% [markdown]
# ### Conclusion
# - imbalanced dataset

# %%
# df.quality.value_counts().plot(
#     kind='bar',
#     title='Quality Distribution',
#     xlabel='Quality',
#     ylabel='Count'
# )
#correct way:
plt.figure(figsize=(4,4))
df.quality.value_counts().plot(
    kind='bar',
)

plt.title("Quality Dist")
plt.xlabel("Quality")
plt.ylabel("Count")
plt.show()

# %%
df.head()

# %%
for column in df.columns:
    sns.histplot(df[column],kde=True)

# %%
#OPTION 1: One plot at a time (clean & simple)

# Select only numerical columns
num_cols = df.select_dtypes(include='number').columns

# Loop through each numerical column
for col in num_cols:
    plt.figure(figsize=(6,4))          # Create a new figure for each column
    sns.histplot(df[col], kde=True)    # Plot histogram with KDE
    plt.title(col)                     # Set plot title
    plt.show()                         # Display and clear the figure

# %%
# OPTION 2: Subplots (all plots in a grid)
import math

# Select only numerical columns
num_cols = df.select_dtypes(include='number').columns

n_cols = 4                           # Number of plots per row
n_rows = math.ceil(len(num_cols) / n_cols)

# Create subplot grid
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
axes = axes.flatten()                  # Flatten axes for easy looping

# Plot each column in its own subplot
for ax, col in zip(axes, num_cols):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(col)

# Remove empty subplots
for ax in axes[len(num_cols):]:
    ax.remove()

plt.tight_layout()                     # Adjust spacing
plt.show()

# %%
# OPTION 3: One plot at a time (manual stepping)

# Select only numerical columns
num_cols = df.select_dtypes(include='number').columns

# Loop through columns one by one
for col in num_cols:
    sns.histplot(df[col], kde=True)    # Plot histogram
    plt.title(col)                     # Set title
    plt.show()                         # Show plot
    input("Press Enter for next plot") # Pause before next plot

# %%
#OPTION 4: FacetGrid (Seaborn-managed layout)

# Select only numerical columns
num_cols = df.select_dtypes(include='number').columns

# Reshape data from wide to long format
df_melted = df[num_cols].melt(
    var_name='Feature',
    value_name='Value'
)

# Create FacetGrid
g = sns.FacetGrid(
    df_melted,
    col='Feature',
    col_wrap=4,
    sharex=False,
    sharey=False
)

# Map histogram to each facet
g.map(sns.histplot, 'Value', kde=True)

plt.show()

# %%
sns.boxplot(x='quality',y='alcohol',data=df)

# %% [markdown]
# ### for univariate, bi-variate and multivariate analysis

# %%
sns.pairplot(df)

# %%
sns.catplot(x='quality',y='alcohol',data=df,kind='box')

# %%
sns.scatterplot(x='alcohol',y='pH',hue='quality',data=df)

# %%
sns.scatterplot(x='alcohol',y='quality',data=df)

# %% [markdown]
# # Flight Price Prediction

# %% [markdown]
# ### FEATURES
# The various features of the cleaned dataset are explained below:
# 1) Airline: The name of the airline company is stored in the airline column. It is a categorical feature having 6 different airlines.
# 2) Flight: Flight stores information regarding the plane's flight code. It is a categorical feature.
# 3) Source City: City from which the flight takes off. It is a categorical feature having 6 unique cities.
# 4) Departure Time: This is a derived categorical feature obtained created by grouping time periods into bins. It stores information about the departure time and have 6 unique time labels.
# 5) Stops: A categorical feature with 3 distinct values that stores the number of stops between the source and destination cities.
# 6) Arrival Time: This is a derived categorical feature created by grouping time intervals into bins. It has six distinct time labels and keeps information about the arrival time.
# 7) Destination City: City where the flight will land. It is a categorical feature having 6 unique cities.
# 8) Class: A categorical feature that contains information on seat class; it has two distinct values: Business and Economy.
# 9) Duration: A continuous feature that displays the overall amount of time it takes to travel between cities in hours.
# 10)Days Left: This is a derived characteristic that is calculated by subtracting the trip date by the booking date.
# 11) Price: Target variable stores information of the ticket price.

# %%
# %pip install -r ../../requirements.txt

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns

# %%
df = pd.read_excel("../../data/002 flight-price.xlsx")

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.shape

# %%
df.head().items

# %%
df.head()

# %%
mew = df["Date_of_Journey"].str.split('/').str[0]
mew

# %%
# cleaning the data:
#first lets clean the date and separate the day, month and year columns
df["Journey_day"]=df["Date_of_Journey"].str.split('/').str[0]
df["Journey_month"]=df["Date_of_Journey"].str.split('/').str[1]
df["Journey_year"]=df["Date_of_Journey"].str.split('/').str[2]

# %%
df.head()

# %%
#now the date of journey column is of no use to us
df.drop('Date_of_Journey',inplace=True,axis=1)

# %%
df.head()

# %%
df.info()

# %%
#still of object type converting them in int:
df["Journey_day"]=df["Journey_day"].astype(int)
df["Journey_month"]=df["Journey_month"].astype(int)
df["Journey_year"]=df["Journey_year"].astype(int)

# %%
df.info()

# %%
df.head(3)

# %%
df['Arrival_Time_No_Date']=df['Arrival_Time'].apply(lambda x:x.split(' ')[0])

# %%
df.head()

# %%
#now arrival time:
df['Arrival_time_hour'] = df['Arrival_Time_No_Date'].str.split(':').str[0]
df['Arrival_time_min'] = df['Arrival_Time_No_Date'].str.split(':').str[1]

# %%
df.head()

# %%
df.drop('Arrival_Time',inplace=True,axis=1)
df.drop('Arrival_Time_No_Date',inplace=True,axis=1)

# %%
df.head()

# %%
df['Arrival_time_hour'] = df['Arrival_time_hour'].astype(int)
df['Arrival_time_min'] = df['Arrival_time_min'].astype(int)

# %%
df.info()

# %%
df.head()

# %%
#now dept time
df['Dep_Time_hour'] = df['Dep_Time'].str.split(':').str[0]
df['Dep_Time_min'] = df['Dep_Time'].str.split(':').str[1]

# %%
df.head()

# %%
df['Dep_Time_hour'] = df['Dep_Time_hour'].astype(int)
df['Dep_Time_min'] = df['Dep_Time_min'].astype(int)

# %%
df.info()

# %%
df.drop('Dep_Time',inplace=True,axis=1)

# %%
df.head()

# %%
df.head()

# %%
#now duration
df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
df['Duration_hour'] = df['Duration'].str.split(' ').str[0].str.split('h').str[0]
df['Duration_min'] = df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
(
    df['Duration']
    .str.extract(r'(\d+)m')
    .astype(float)
    .fillna(0)
    .astype(int)
)

# %%
(
    df['Duration']
    .str.extract(r'(\d+)h')
    .astype(float)
    .fillna(0)
    .astype(int)
)

# %%
# well as per GPT sensei this approach is wrong
# so i will go with his approach as it seems more optimal:
df['Duration_hours'] = (
    df['Duration']
    .str.extract(r'(\d+)h')
    .astype(float)
    .fillna(0)
    .astype(int)
)

df['Duration_minutes'] = (
    df['Duration']
    .str.extract(r'(\d+)m')
    .astype(float)
    .fillna(0)
    .astype(int)
)

# %%
df.head(2)

# %%
df.drop('Duration',inplace=True,axis=1)

# %%
df.info()

# %%
#lets set it up like this:
df['Duration_total_min'] = df['Duration_hours'] * 60 + df['Duration_minutes']

# %%
df.head()

# %%
df.info()

# %%
#categorical Features!!
df['Route']

# %%
# since we are not in need of routes as we already have
# destination and number of stops we will drop it
# as we should but me a data hoarder!
# df.drop('Route',inplace=True,axis=1)

# %%
# Total Stops
df['Total_Stops'].unique()

# %%
sns.histplot(x='Total_Stops',data=df,kde=True,legend=True)

# %%
df['Total_Stops'].mode()

# %%
df['Total_Stops'].head(4)

# %%
df['Total_Stops'].value_counts()

# %%
df['Total_Stops']=df['Total_Stops'].map({
    "non-stop":0,
    "1 stop":1,
    "2 stops":2,
    "3 stops":3,
    "4 stops":4,
    np.nan:1, #cuz the mode of it is 1
})

# %%
df['Total_Stops'].value_counts()

# %%
df.head()

# %%
# now for the rest categorical features
df['Airline'].unique()

# %%
df['Source'].unique()

# %%
df['Additional_Info'].unique()

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()

# %%
encoder.fit_transform(df[['Airline','Source','Additional_Info','Destination']]).toarray()

# %%
df_categorical_remains=pd.DataFrame(encoder.fit_transform(df[['Airline','Source','Additional_Info','Destination']]).toarray(),columns=encoder.get_feature_names_out())

# %%
df=pd.concat([df,df_categorical_remains],axis=1)

# %%
df.head()

# %%
df.drop('Airline',inplace=True,axis=1)
df.drop('Source',inplace=True,axis=1)
df.drop('Additional_Info',inplace=True,axis=1)

# %%
df.drop('Destination',inplace=True,axis=1)

# %%
df.info()

# %%
df.drop('Duration_hour',inplace=True,axis=1)
df.drop('Duration_min',inplace=True,axis=1)

# %%
df.info()

# %%
[col for col in df.columns if 'Additional_Info_No' in col]

# %%
df['Additional_Info_No Info'] = df[['Additional_Info_No Info','Additional_Info_No info']].max(axis=1)
df = df.drop(columns=['Additional_Info_No info'])

# %%
df.info()

# %%
df.duplicated().sum()

# %%
df.isna().sum()

# %%
df['Price'].describe()

# %%
df['Duration_total_min'].describe()

# %%
df[df.duplicated(keep=False)].head(3)

# %% [markdown]
# 1️⃣ Things you could improve / “wrong” (minor points)
#
# Duplicate / inconsistent column names in Additional_Info
#
# You have:
#
# 'Additional_Info_No Info',
# 'Additional_Info_No info'
#
#
# Same meaning, different casing → can confuse analysis or modeling.
#
# Best practice: unify these into one column before using them.
#
# df['Additional_Info_No Info'] = df[['Additional_Info_No Info','Additional_Info_No info']].max(axis=1)
# df = df.drop(columns=['Additional_Info_No info'])
#
#
# Route column is still object
#
# You haven’t feature-engineered it (like extracting stops, layovers).
#
# Not “wrong,” but it’s currently unusable in models.
#
# Departure / Arrival minutes separated
#
# Not wrong, but can be simplified into total minutes like you did for duration.
#
# e.g., Dep_Time_total_min = Dep_Time_hour*60 + Dep_Time_min
#
# Minor redundancy in Additional_Info
#
# Columns like 1 Long layover, 2 Long layover may overlap with other features; keep an eye on correlated columns.
#
# 2️⃣ What more you could do for EDA / preprocessing
#
# Check duplicates / missing rows
#
# df.duplicated().sum()
# df.isna().sum()
#
#
# Check numeric distributions
#
# df['Price'].describe()
# df['Duration_total_min'].describe()
#
#
# Visual EDA
#
# Price vs Airline / Source / Destination
#
# Histogram of Duration_total_min
#
# Boxplot of Price vs categorical features
#
# Check correlation / multicollinearity
#
# Especially between one-hot columns
#
# Data cleaning
#
# Merge columns with same meaning (No Info)
#
# Correct any outliers (minutes >= 60 etc.)
#
# Optional: convert times to single features
#
# Dep_Time_total_min
#
# Arrival_time_total_min
#
# 3️⃣ Explanation of your line
# [col for col in df.columns if 'Additional_Info_No' in col]
#
#
# This is a list comprehension.
#
# It goes through all column names in df.columns.
#
# Includes only columns that contain the substring 'Additional_Info_No'.
#
# Output:
#
# ['Additional_Info_No Info',
#  'Additional_Info_No check-in baggage included',
#  'Additional_Info_No info']
#
#
# You used it to detect columns with similar meaning, which is exactly right.
#
# ✅ Summary
#
# Nothing major is “wrong”, your data is clean and usable.
#
# Minor issues:
#
# Duplicate / inconsistent No Info columns
#
# Route still object (feature engineering possible)
#
# Separate hour/min columns could be combined for simplicity
#
# Next steps:
#
# Merge duplicates
#
# Create total minutes for times
#
# Start visual EDA and correlation checks
#
# Prepare final modeling DataFrame

# %% [markdown]
# # PlayStore Data
